# %% [markdown]
# <a href="https://colab.research.google.com/github/Shlok-Saxena02/COLLEGE_LAB_REPOSITORY/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import numpy as np
import matplotlib.pyplot as plt
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr
def time_selection_sort(n, trials=3):
    times = []
    for _ in range(trials):
        arr = np.random.randint(0, 10**6, size=n).tolist()
        start = time.perf_counter()
        selection_sort(arr)
        end = time.perf_counter()
        times.append(end - start)
    return sum(times) / len(times)
def main():
    sizes = [100, 200, 400, 800, 1600, 3200]
    trials = 3
    results = []
    print("Measuring selection sort runtimes...")
    for n in sizes:
        print(f"  n = {n}: running {trials} trials...")
        avg_time = time_selection_sort(n, trials=trials)
        results.append((n, avg_time))
        print(f"    average time: {avg_time:.6f} seconds")
    ns = np.array([r[0] for r in results])
    times = np.array([r[1] for r in results])
    n2 = ns**2
    scale = times[0] / n2[0]
    n2_scaled = scale * n2
    plt.figure(figsize=(8,5))
    plt.plot(ns, times, 'o-', label='Measured time (selection sort)')
    plt.plot(ns, n2_scaled, '--', label='Scaled n^2')
    plt.xlabel('Input size n')
    plt.ylabel('Time (seconds)')
    plt.title('Selection Sort: Time vs Input Size')
    plt.xscale('log')
    plt.yscale('log')
    plt.grid(True, which='both', ls='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()
    print("\nSummary:")
    print(" n\taverage_time(s)")
    for n, t in results:
        print(f"{n}\t{t:.6f}")
if __name__ == "__main__":
    main()
# Out:
# Measuring selection sort runtimes...
#   n = 100: running 3 trials...
#     average time: 0.000159 seconds
#   n = 200: running 3 trials...
#     average time: 0.000549 seconds
#   n = 400: running 3 trials...
#     average time: 0.002423 seconds
#   n = 800: running 3 trials...
#     average time: 0.009910 seconds
#   n = 1600: running 3 trials...
#     average time: 0.039720 seconds
#   n = 3200: running 3 trials...
#     average time: 0.213901 seconds
# Summary:
#  n	average_time(s)
# 100	0.000159
# 200	0.000549
# 400	0.002423
# 800	0.009910
# 1600	0.039720
# 3200	0.213901

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import numpy as np
import matplotlib.pyplot as plt
def merge(left, right):
    merged = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            merged.append(left[i])
            i += 1
        else:
            merged.append(right[j])
            j += 1
    merged.extend(left[i:])
    merged.extend(right[j:])
    return merged
def merge_sort(arr):
    if len(arr) <= 1:
        return arr[:]
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)
def time_merge_sort(n, trials=5):
    times = []
    for _ in range(trials):
        arr = np.random.randint(0, 10**6, size=n).tolist()
        start = time.perf_counter()
        merge_sort(arr)
        end = time.perf_counter()
        times.append(end - start)
    return sum(times) / len(times)
def main():
    sizes = [1000, 2000, 4000, 8000, 16000, 32000]
    trials = 5
    results = []
    print("Measuring merge sort runtimes...")
    for n in sizes:
        print(f"  n = {n}: running {trials} trials...")
        avg_time = time_merge_sort(n, trials=trials)
        results.append((n, avg_time))
        print(f"    average time: {avg_time:.6f} seconds")
    ns = np.array([r[0] for r in results])
    times = np.array([r[1] for r in results])
    nlogn = ns * np.log2(ns)
    scale = times[0] / nlogn[0]
    nlogn_scaled = scale * nlogn
    plt.figure(figsize=(8,5))
    plt.plot(ns, times, 'o-', label='Measured time (merge sort)')
    plt.plot(ns, nlogn_scaled, '--', label='Scaled n log2 n')
    plt.xlabel('Input size n')
    plt.ylabel('Time (seconds)')
    plt.title('Merge Sort: Time vs Input Size')
    plt.xscale('log')
    plt.yscale('log')
    plt.grid(True, which='both', ls='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()
    print("\nSummary:")
    print(" n\taverage_time(s)")
    for n, t in results:
        print(f"{n}\t{t:.6f}")
if __name__ == "__main__":
    main()
# Out:
# Measuring merge sort runtimes...
#   n = 1000: running 5 trials...
#     average time: 0.001403 seconds
#   n = 2000: running 5 trials...
#     average time: 0.002754 seconds
#   n = 4000: running 5 trials...
#     average time: 0.005960 seconds
#   n = 8000: running 5 trials...
#     average time: 0.012956 seconds
#   n = 16000: running 5 trials...
#     average time: 0.027718 seconds
#   n = 32000: running 5 trials...
#     average time: 0.062215 seconds
# Summary:
#  n	average_time(s)
# 1000	0.001403
# 2000	0.002754
# 4000	0.005960
# 8000	0.012956
# 16000	0.027718
# 32000	0.062215

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import numpy as np
import matplotlib.pyplot as plt
def quicksort(arr, low, high):
    if low < high:
        pivot_index = partition(arr, low, high)
        quicksort(arr, low, pivot_index - 1)
        quicksort(arr, pivot_index + 1, high)
def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i+1], arr[high] = arr[high], arr[i+1]
    return i + 1
def time_quicksort(n, trials=5):
    times = []
    for _ in range(trials):
        arr = np.random.randint(0, 10**6, size=n).tolist()
        start = time.perf_counter()
        quicksort(arr, 0, len(arr)-1)
        end = time.perf_counter()
        times.append(end - start)
    return sum(times) / len(times)
def main():
    sizes = [1000, 2000, 4000, 8000, 16000, 32000]
    trials = 5
    results = []
    print("Measuring quicksort runtimes...")
    for n in sizes:
        print(f"  n = {n}: running {trials} trials...")
        avg_time = time_quicksort(n, trials=trials)
        results.append((n, avg_time))
        print(f"    average time: {avg_time:.6f} seconds")
    ns = np.array([r[0] for r in results])
    times = np.array([r[1] for r in results])
    nlogn = ns * np.log2(ns)
    scale = times[0] / nlogn[0]
    nlogn_scaled = scale * nlogn
    plt.figure(figsize=(8,5))
    plt.plot(ns, times, 'o-', label='Measured time (quicksort)')
    plt.plot(ns, nlogn_scaled, '--', label='Scaled n log2 n')
    plt.xlabel('Input size n')
    plt.ylabel('Time (seconds)')
    plt.title('Quicksort: Time vs Input Size')
    plt.xscale('log')
    plt.yscale('log')
    plt.grid(True, which='both', ls='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()
    print("\nSummary:")
    print(" n\taverage_time(s)")
    for n, t in results:
        print(f"{n}\t{t:.6f}")
if __name__ == "__main__":
    main()
# Out:
# Measuring quicksort runtimes...
#   n = 1000: running 5 trials...
#     average time: 0.000846 seconds
#   n = 2000: running 5 trials...
#     average time: 0.001872 seconds
#   n = 4000: running 5 trials...
#     average time: 0.004337 seconds
#   n = 8000: running 5 trials...
#     average time: 0.008688 seconds
#   n = 16000: running 5 trials...
#     average time: 0.019421 seconds
#   n = 32000: running 5 trials...
#     average time: 0.042449 seconds
# Summary:
#  n	average_time(s)
# 1000	0.000846
# 2000	0.001872
# 4000	0.004337
# 8000	0.008688
# 16000	0.019421
# 32000	0.042449

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
# Creating a random value (uniform)
import random
from datetime import datetime
n_max = 10
ms = datetime.now().microsecond // 1000
random.seed(ms)
numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))
print("Generated numbers:", numbers)
# Out:
# Generated numbers: [574, 44, 842, 234, 72, 105, 777, 247, 301, 557]

# %%
import copy
import timeit
import random
n_list = [100, 500, 1000]
numbers = [random.randint(0, 10000) for _ in range(max(n_list))]
def quicksort(arr):
    arr.sort()
def merge_sort(arr):
    arr.sort()
def selection_sort(arr):
    arr.sort()
a_time = []
b_time = []
c_time = []
for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quicksort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    selection_sort(c)
    c_time.append((timeit.default_timer() - start_time) * 1000)

print("Quicksort times:", a_time)
print("Merge sort times:", b_time)
print("Selection sort times:", c_time)
# Out:
# Quicksort times: [0.008960000059232698, 0.0405599998885009, 0.06729899996571476]
# Merge sort times: [0.004590000116877491, 0.02831000006153772, 0.05151999994268408]
# Selection sort times: [0.0024700000267330324, 0.018039999986285693, 0.03946000015275786]

# %%
import numpy as np
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
